# %%
# !pip install -q -r requirements.txt

# %%
from langchain.document_loaders import PyPDFLoader
pdf_path = './data/menu-5 (1).pdf'
loader = PyPDFLoader(pdf_path)
pages = loader.load_and_split()

# %%
pages
# Out:
# [Document(metadata={'source': './data/menu-5 (1).pdf', 'page': 0}, page_content='DRINKS\nDIVERSIONS\nKNOCK  OUTS\nDRINKS  &  DIVERSIONS\nKIRKWOOD\nBITES  & SHAREABLES\nPOPCORN...................................................................................................... 3.5\nSOFT PRETZEL W/ MUSTARD.......................................................................6.75\nFRIED PICKLE CHIPS ................................................................................... 8.5\nMOZZARELLA CHEESE STICKS................................................................... 10.5\nJALAPEÑO POPPERS....................................................................................... 9\nBASKET OF ONION RINGS............................................................................ 7.5\nBASKET OF FRENCH FRIES..........................................................................6.75\nFUNNEL CAKE FRIES................................................................................
# ...

# %%
print(pages[0].page_content)
# Out:
# DRINKS
# DIVERSIONS
# KNOCK  OUTS
# DRINKS  &  DIVERSIONS
# KIRKWOOD
# BITES  & SHAREABLES
# POPCORN...................................................................................................... 3.5
# SOFT PRETZEL W/ MUSTARD.......................................................................6.75
# FRIED PICKLE CHIPS ................................................................................... 8.5
# MOZZARELLA CHEESE STICKS................................................................... 10.5
# JALAPEÑO POPPERS....................................................................................... 9
# BASKET OF ONION RINGS............................................................................ 7.5
# BASKET OF FRENCH FRIES..........................................................................6.75
# FUNNEL CAKE FRIES......................................................................................7.5
# FAVORITES
# BURGERS & SANDWICHES
# ...

# %%
import base64
from core.utils import load_image
def encode_image(image_path):
    """Encodes an image to base64 string."""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
img_path = "./data/menu-4 (1).png"
print(load_image(img_path))
# Out:
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the model
model = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# Download and encode the image

img_path = "./data/menu-4 (1).png"
image_data = load_image(img_path)
# Create a message with the image
message = HumanMessage(
    content=[
        {"type": "text", "text": "EXTRACT MENUE FROM IMAGE"},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/jpeg;base64,{image_data}"},
        },
    ],
)

# Invoke the model with the message
response = model.invoke([message])

# Print the model's response
print(response.content)
# Out:
# Here's a menu extracted from the image:
#
# **Food & Drinks:**
#
# * **The Almond Butter Toast**
# * **Immune Booster**
# * **The Kids Cheesy Wrap**
# * **The Intense One** (smoothie)
# * **The So Basic One** (smoothie)
# * **The Mangoes 'N Cream One** (smoothie)

# %%
import os

def get_files_with_extensions(folder_path, valid_extensions):
   files_by_ext = {}
   for file in os.listdir(folder_path):
       if os.path.isfile(os.path.join(folder_path, file)):
           if file.lower().endswith(tuple(valid_extensions)):
                ext = file.split(".")[-1]
                files_by_ext.setdefault(ext, []).append(f"{folder_path}/{file}")

   return files_by_ext

# Usage
folder = "./data"
extensions = ('.pdf', '.png', '.html') 
files = get_files_with_extensions(folder, extensions)

# %%
files
# Out:
# {'html': ['./data/menu-1 (1).html', './data/menu-2 (1).html'],
#  'pdf': ['./data/menu-5 (1).pdf', './data/menu-6 (1).pdf'],
#  'png': ['./data/menu-4 (1).png']}
